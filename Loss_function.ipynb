# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=100, n_features=2,  n_informative=2, n_redundant=0, n_classes=2, n_clusters_per_class=1,  hypercube= False,  random_state=41)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,7))
plt.scatter(X[:,0] , X[:,1] ,c=y, cmap = 'winter' , s =100)

# %%
def perceptron(X, y):
    w1=w2=b= 1
    lr = 0.1
    
    for j in range(1000):
        for i in range(X.shape[0]):
            
            z = w1*X[1][0]+w2*X[1][1] +b
            
            
            if z*y[i] < 0:
                
                w1 = w1 * lr*y[i] *X[1][0]
                w2 = w2 * lr*y[i] *X[1][1]
                b = b +lr*y[i]
                
                return w1, w2, b

# %%
w1,w2,b = perceptron(X,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 w1,w2,b = perceptron(X,y)
#
# TypeError: cannot unpack non-iterable NoneType object
